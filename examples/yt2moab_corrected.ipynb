# %%
import yt
ds = yt.load("test.h5m") #moab file
print ds.dataset_type
p = yt.SlicePlot(ds, 'z', 'Density')
p.show()
# Out:
# yt : [INFO     ] 2015-08-05 13:58:39,485 Parameters: current_time              = 0.0
# yt : [INFO     ] 2015-08-05 13:58:39,486 Parameters: domain_dimensions         = [ 1.  1.  1.]
# yt : [INFO     ] 2015-08-05 13:58:39,486 Parameters: domain_left_edge          = [ 0.  0.  0.]
# yt : [INFO     ] 2015-08-05 13:58:39,487 Parameters: domain_right_edge         = [ 1.  1.  1.]
# yt : [INFO     ] 2015-08-05 13:58:39,488 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2015-08-05 13:58:39,507 Loading field plugins.
# yt : [INFO     ] 2015-08-05 13:58:39,509 Loaded angular_momentum (8 new fields)
# yt : [INFO     ] 2015-08-05 13:58:39,510 Loaded astro (15 new fields)
# yt : [INFO     ] 2015-08-05 13:58:39,510 Loaded cosmology (22 new fields)
# yt : [INFO     ] 2015-08-05 13:58:39,511 Loaded fluid (64 new fields)
# yt : [INFO     ] 2015-08-05 13:58:39,512 Loaded fluid_vector (96 new fields)
# yt : [INFO     ] 2015-08-05 13:58:39,513 Loaded geometric (112 new fields)
# ...

# %%
ds1 = yt.load("/home/shriwise/scratch/DD0011/DD0011") #original dataset
print ds1.dataset_type
p = yt.SlicePlot(ds1, 'z', 'Density')
p.show()
# Out:
# yt : [INFO     ] 2015-08-05 13:58:44,407 Parameters: current_time              = 1
# yt : [INFO     ] 2015-08-05 13:58:44,408 Parameters: domain_dimensions         = [64 64  1]
# yt : [INFO     ] 2015-08-05 13:58:44,408 Parameters: domain_left_edge          = [ 0.  0.  0.]
# yt : [INFO     ] 2015-08-05 13:58:44,409 Parameters: domain_right_edge         = [ 1.  1.  1.]
# yt : [INFO     ] 2015-08-05 13:58:44,409 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2015-08-05 13:58:44,414 Gathering a field list (this may take a moment.)
# yt : [INFO     ] 2015-08-05 13:58:44,441 Loading field plugins.
# yt : [INFO     ] 2015-08-05 13:58:44,441 Loaded angular_momentum (8 new fields)
# yt : [INFO     ] 2015-08-05 13:58:44,441 Loaded astro (15 new fields)
# yt : [INFO     ] 2015-08-05 13:58:44,442 Loaded cosmology (22 new fields)
# yt : [INFO     ] 2015-08-05 13:58:44,442 Loaded fluid (63 new fields)
# yt : [INFO     ] 2015-08-05 13:58:44,443 Loaded fluid_vector (95 new fields)
# ...

# %%
print ds.field_list
# Out:
# [('moab', u'Density'), ('moab', u'TotalEnergy'), ('moab', u'x-velocity'), ('moab', u'y-velocity')]

# %%
p = yt.SlicePlot(ds, 'z', 'y-velocity')
p.show()
# Out:
# yt : [INFO     ] 2015-08-05 13:58:52,719 xlim = 0.000000 1.000000
# yt : [INFO     ] 2015-08-05 13:58:52,720 ylim = 0.000000 1.000000
# yt : [INFO     ] 2015-08-05 13:58:52,723 xlim = 0.000000 1.000000
# yt : [INFO     ] 2015-08-05 13:58:52,723 ylim = 0.000000 1.000000
# yt : [INFO     ] 2015-08-05 13:58:52,729 Making a fixed resolution buffer of (('moab', 'y-velocity')) 800 by 800
# yt : [WARNING  ] 2015-08-05 13:58:52,755 Plot image for field ('moab', 'y-velocity') has both positive and negative values. Min = -0.446835, Max = 0.446835.
# yt : [WARNING  ] 2015-08-05 13:58:52,755 Switching to symlog colorbar scaling unless linear scaling is specified later
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
